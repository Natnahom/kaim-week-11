# %%
import os, sys

notebook_dir = os.getcwd()

#add path
sys.path.append(os.path.abspath(os.path.join(notebook_dir, '..')))

# %%
from scripts.fetch_data import *
from scripts.clean_data import *
from scripts.EDA import *
from scripts.outlier_detection import *

# %%
# Define tickers and date range
tickers = ['TSLA', 'BND', 'SPY']
start_date = '2015-01-01'
end_date = '2025-01-31'

# Fetch historical data
data = fetch_historical_data(tickers, start_date, end_date)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# {'TSLA': Price            Close        High         Low        Open    Volume  \
#  Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
#  Date
#  2015-01-02   14.620667   14.883333   14.217333   14.858000  71466000
#  2015-01-05   14.006000   14.433333   13.810667   14.303333  80527500
#  2015-01-06   14.085333   14.280000   13.614000   14.004000  93928500
#  2015-01-07   14.063333   14.318667   13.985333   14.223333  44526000
#  2015-01-08   14.041333   14.253333   14.000667   14.187333  51637500
#  ...                ...         ...         ...         ...       ...
#  2025-01-24  406.579987  418.880005  405.779999  414.450012  56427100
#  2025-01-27  397.149994  406.690002  389.000000  394.799988  58125500
#  2025-01-28  398.089996  400.589996  386.500000  396.910004  48910700
#  2025-01-29  389.100006  398.589996  384.480011  395.209991  68033600
#  2025-01-30  400.279999  412.500000  384.410004  410.779999  98092900
#
#  Price            Date
#  Ticker
#  Date
#  2015-01-02 2015-01-02
#  2015-01-05 2015-01-05
#  2015-01-06 2015-01-06
#  2015-01-07 2015-01-07
#  2015-01-08 2015-01-08
#  ...               ...
#  2025-01-24 2025-01-24
#  2025-01-27 2025-01-27
#  2025-01-28 2025-01-28
#  2025-01-29 2025-01-29
#  2025-01-30 2025-01-30
#
#  [2535 rows x 6 columns],
#  'BND': Price           Close       High        Low       Open   Volume       Date
#  Ticker            BND        BND        BND        BND      BND
#  Date
#  2015-01-02  62.573105  62.603389  62.398973  62.406545  2218800 2015-01-02
#  2015-01-05  62.754848  62.777560  62.611000  62.641284  5820100 2015-01-05
#  2015-01-06  62.936543  63.125814  62.860835  62.860835  3887600 2015-01-06
#  2015-01-07  62.974396  63.050103  62.875977  62.944112  2433400 2015-01-07
#  2015-01-08  62.875912  62.921335  62.815344  62.921335  1873400 2015-01-08
#  ...               ...        ...        ...        ...      ...        ...
#  2025-01-24  71.805977  71.855810  71.636531  71.766106  5555700 2025-01-24
#  2025-01-27  72.184738  72.204677  72.025262  72.104996  8621200 2025-01-27
#  2025-01-28  72.144867  72.154837  71.975421  72.154837  4424300 2025-01-28
#  2025-01-29  72.104996  72.254510  71.935550  72.194707  5780200 2025-01-29
#  2025-01-30  72.204674  72.294378  72.144864  72.224605  5622300 2025-01-30
#
#  [2535 rows x 6 columns],
#  'SPY': Price            Close        High         Low        Open     Volume  \
#  Ticker             SPY         SPY         SPY         SPY        SPY
#  Date
#  2015-01-02  172.592850  173.811083  171.542657  173.391006  121465900
#  2015-01-05  169.475937  171.702341  169.165084  171.534312  169632600
#  2015-01-06  167.879608  170.316050  167.073055  169.786749  209151400
#  2015-01-07  169.971573  170.316039  168.770159  169.223836  125346700
#  2015-01-08  172.987732  173.206180  171.383047  171.399841  147217800
#  ...                ...         ...         ...         ...        ...
#  2025-01-24  607.969971  610.780029  606.799988  609.809998   34604700
#  2025-01-27  599.369995  599.690002  594.640015  594.809998   70361100
#  2025-01-28  604.520020  605.369995  597.250000  600.619995   44433300
#  2025-01-29  601.809998  604.130005  599.219971  603.719971   37177400
#  2025-01-30  605.039978  606.599976  600.719971  603.960022   39281300
#
#  Price            Date
#  Ticker
#  Date
#  2015-01-02 2015-01-02
#  2015-01-05 2015-01-05
#  2015-01-06 2015-01-06
#  2015-01-07 2015-01-07
#  2015-01-08 2015-01-08
#  ...               ...
#  2025-01-24 2025-01-24
#  2025-01-27 2025-01-27
#  2025-01-28 2025-01-28
#  2025-01-29 2025-01-29
#  2025-01-30 2025-01-30
#
#  [2535 rows x 6 columns]}

# %%
# Clean and understand data
cleaned_data = clean_and_understand_data(data)
# Out:
# Missing values in TSLA:
# Price   Ticker
# Close   TSLA      0
# High    TSLA      0
# Low     TSLA      0
# Open    TSLA      0
# Volume  TSLA      0
# dtype: int64
#
# Basic statistics for TSLA:
# Price         Close         High          Low         Open        Volume  \
# Ticker         TSLA         TSLA         TSLA         TSLA          TSLA
# count   2535.000000  2535.000000  2535.000000  2535.000000  2.535000e+03
# mean     117.848209   120.474827   115.097514   117.877662  1.120308e+08
# min        9.578000    10.331333     9.403333     9.488000  1.062000e+07
# 25%       17.228000    17.527667    16.942000    17.259334  6.680295e+07
# 50%       30.298000    32.329334    29.760000    31.299999  9.264180e+07
# 75%      221.525002   226.696671   217.061661   222.653336  1.294283e+08
# max      479.859985   488.540009   457.510010   475.899994  9.140820e+08
# std      116.508288   119.236025   113.698930   116.611575  7.387509e+07
#
# Price                            Date
# Ticker
# count                            2535
# mean    2020-01-14 14:32:31.242603776
# min               2015-01-02 00:00:00
# 25%               2017-07-10 12:00:00
# 50%               2020-01-15 00:00:00
# 75%               2022-07-21 12:00:00
# max               2025-01-30 00:00:00
# std                               NaN
# Missing values in BND:
# Price   Ticker
# Close   BND       0
# High    BND       0
# Low     BND       0
# Open    BND       0
# Volume  BND       0
# dtype: int64
#
# Basic statistics for BND:
# Price         Close         High          Low         Open        Volume  \
# Ticker          BND          BND          BND          BND           BND
# count   2535.000000  2535.000000  2535.000000  2535.000000  2.535000e+03
# mean      69.289451    69.391261    69.186012    69.293224  4.233200e+06
# min       61.860863    61.937369    61.822624    61.891457  0.000000e+00
# 25%       65.565277    65.630173    65.475471    65.552724  2.057700e+06
# 50%       68.329132    68.457869    68.169747    68.310219  3.805800e+06
# 75%       72.879932    72.946425    72.728794    72.845705  5.626700e+06
# max       78.823265    78.920180    78.788028    78.884950  3.193720e+07
# std        4.792145     4.800408     4.782142     4.793199  2.796083e+06
#
# Price                            Date
# Ticker
# count                            2535
# mean    2020-01-14 14:32:31.242603776
# min               2015-01-02 00:00:00
# 25%               2017-07-10 12:00:00
# 50%               2020-01-15 00:00:00
# 75%               2022-07-21 12:00:00
# max               2025-01-30 00:00:00
# std                               NaN
# Missing values in SPY:
# Price   Ticker
# Close   SPY       0
# High    SPY       0
# Low     SPY       0
# Open    SPY       0
# Volume  SPY       0
# dtype: int64
#
# Basic statistics for SPY:
# Price         Close         High          Low         Open        Volume  \
# Ticker          SPY          SPY          SPY          SPY           SPY
# count   2535.000000  2535.000000  2535.000000  2535.000000  2.535000e+03
# mean     316.067402   317.725660   314.157888   316.021384  8.714655e+07
# min      156.800781   157.864075   154.676912   156.354882  2.027000e+07
# 25%      214.841972   215.702207   214.206908   214.972500  5.862005e+07
# 50%      277.117859   277.919519   276.073581   277.230781  7.642870e+07
# 75%      405.869202   409.134325   402.830873   406.100240  1.018866e+08
# max      609.750000   610.780029   606.799988   609.809998  5.072443e+08
# std      117.926910   118.486410   117.269902   117.921618  4.487253e+07
#
# Price                            Date
# Ticker
# count                            2535
# mean    2020-01-14 14:32:31.242603776
# min               2015-01-02 00:00:00
# 25%               2017-07-10 12:00:00
# 50%               2020-01-15 00:00:00
# 75%               2022-07-21 12:00:00
# max               2025-01-30 00:00:00
# std                               NaN
# c:\Users\pc\Desktop\10_Academy\Week-11\kaim-week-11\scripts\clean_data.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# c:\Users\pc\Desktop\10_Academy\Week-11\kaim-week-11\scripts\clean_data.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# c:\Users\pc\Desktop\10_Academy\Week-11\kaim-week-11\scripts\clean_data.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
# Perform EDA
plot_closing_price(cleaned_data)

# %%
# Perform EDA
calculate_daily_returns(cleaned_data)

# %%
# Perform EDA
analyze_volatility(cleaned_data)

# %%
# Decompose time series for TSLA
decompose_time_series(cleaned_data, 'TSLA')

# %%
# Detect outliers for TSLA
detect_outliers(cleaned_data, 'TSLA')
# Out:
# Outliers in TSLA:
# Empty DataFrame
# Columns: [(Date, ), (Daily Return, )]
# Index: []

# %%
# Decompose time series for BND
decompose_time_series(cleaned_data, 'BND')

# %%
# Detect outliers for BND
detect_outliers(cleaned_data, 'BND')
# Out:
# Outliers in BND:
# Empty DataFrame
# Columns: [(Date, ), (Daily Return, )]
# Index: []

# %%
# Decompose time series for SPY
decompose_time_series(cleaned_data, 'SPY')

# %%
# Detect outliers for SPY
detect_outliers(cleaned_data, 'SPY')
# Out:
# Outliers in SPY:
# Empty DataFrame
# Columns: [(Date, ), (Daily Return, )]
# Index: []
